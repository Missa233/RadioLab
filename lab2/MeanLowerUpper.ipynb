# %%
import numpy as np
import matplotlib.pyplot as plt
import spectra as s

# %%
meanspec = np.load('_uppermean.npz')['data']

# %%
meanspecl = np.load('lowerrmean.npz')['data']

# %%
plt.plot(np.fft.fftshift(meanspec))
plt.show()

# %%
plt.plot(np.fft.fftshift(meanspecl))
plt.show()

# %%
soff = meanspecl[:int(len(meanspecl)/2)]
soff = np.append(soff, meanspec[int(len(meanspec)/2):])

# %%
plt.plot(np.fft.fftshift(soff))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
son = meanspec[:int(len(meanspec)/2)]
son = np.append(son, meanspecl[int(len(meanspecl)/2):])

# %%
plt.plot(np.fft.fftshift(son))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sline = son/soff

# %%
# %matplotlib notebook
plt.plot(np.fft.fftshift(sline))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(np.fft.fftshift(soff))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.savez('soff.npz', data=soff)

# %%
import numpy as np

# %%
import spectra as s

# %%
import matplotlib.pyplot as plt

# %%
uppera = np.array([])
upperb = np.array([])

# %%
for i in range(10):
    npz = np.load('_upper/_upper' + str(i) + '.npz')
    data = npz['data']
    data.shape = (2, -1)
    uppera = np.append(uppera, data[0]*0.1/(2**15))
    upperb = np.append(upperb, 1j*(data[1]*0.1/(2**15)))

# %%
uppera
# Out:
# array([ 0.01015625,  0.0171875 ,  0.02890625, ..., -0.04296875,
#        -0.0390625 ,  0.        ])

# %%
datac = uppera + upperb
datac.shape = (-1, 16000)
ft_data = np.fft.fft(datac, axis=1)
meanspec = np.mean(np.abs(ft_data)**2, axis=0)

# %%
print(meanspec)

# %%
plt.plot(meanspec)

# %%
# %matplotlib notebook
s.plot_power(meanspec, 'meanupper')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.savez('meanspecupper', data=meanspec)

# %%
lowera = np.array([])
lowerb = np.array([])

# %%
for i in range(10):
    npz = np.load('retakelower/retakelower' + str(i) + '.npz')
    data = npz['data']
    data.shape = (2, -1)
    lowera = np.append(lowera, data[0]*100/(2**15))
    lowerb = np.append(lowerb, 1j*(data[1]*100/(2**15)))

# %%
datacl = lowera + lowerb
datacl.shape = (-1, 16000)
ft_datal = np.fft.fft(datacl, axis=1)
meanspecl = np.mean(np.abs(ft_datal)**2, axis=0)

# %%
s.plot_power(meanspecl, 'meanlower')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.savez('meanspeclower', data=meanspecl)

# %%
half = len(meanspecl)/2
onl = meanspecl[:int(half)]
onu = meanspec[int(half):]
son = np.append(onl, onu)

# %%
s.plot_power(son, 'son')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
half = len(meanspecl)/2
offu = meanspec[:int(half)]
offl = meanspecl[int(half):]
soff = np.append(offl, offu)

# %%
s.plot_power(soff, 'soff')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s.plot_power(son/soff, 'line shape')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
open75 = np.array([2.0, 3.9, 6.0, 8.0, 10.0, 12.0, 14.0, 16.0, 18.0, 20.0, 22.0, 24.0, 26.0, 27.9, 30.0, 31.9, 33.9, 42.0, 44.0, 46.0, 48.0, 49.9])

# %%
shut75 = np.array([2.4, 4.4, 6.3, 8.4, 10.4, 12.4, 14.4, 16.3, 18.4, 20.4, 22.4, 24.3, 26.4, 28.4, 30.3, 32.4, 34.4, 36.3, 38.4, 40.4, 42.3, 44.3, 46.4, 48.4, 50.3])

# %%
np.savez('openshut75', open75 = open75, shut75=shut75)

# %%
seven5 = np.load('openshut75.npz')

# %%
open75 = seven5['open75']

# %%
open8 = np.array([2.0, 3.8, 5.8, 7.7, 9.5, 11.4, 13.2, 15.1, 17.0, 18.9, 20.7, 22.6, 24.5, 26.3, 28.2, 30.1, 32.0, 33.8, 35.7, 37.6, 39.5, 41.3, 45.1, 46.9, 48.8, 50.7])

# %%
shut8 = np.array([0.8, 2.7, 4.6, 6.4, 8.3, 10.2, 12.1, 14.0, 15.8, 17.7, 19.5, 21.3, 23.3, 25.2, 27.0, 28.9, 30.9, 32.7, 34.5, 36.5, 38.3, 40.2, 42.0, 43.9, 45.8, 47.6, 49.6, 51.4])

# %%
open85 = np.array([2.1, 3.9, 5.6, 7.4, 9.2, 10.9, 12.7, 14.5, 16.2, 17.9, 19.7, 21.5, 23.2, 25.0, 26.8, 28.5, 30.3, 32.1, 33.9, 35.7, 37.4, 39.1, 41.0, 42.7, 44.4, 46.2, 47.9, 49.7, 41.5])

# %%
shut85 = np.array([2.4, 4.1, 5.9, 7.6, 9.4, 11.2, 13.0, 14.7, 16.5, 18.3, 20.0, 21.8, 23.6, 25.3, 27.1, 28.9, 30.6, 32.4, 34.2, 35.9, 37.7, 39.4, 41.2, 43.0, 44.8, 46.5, 48.3, 50.1])

# %%
open9 = np.array([2.1, 3.8, 5.5, 7.1, 8.9, 10.5, 12.1, 13.8, 15.5, 17.2, 18.8, 20.5, 22.2, 23.9, 25.5, 27.2, 28.8, 30.5, 32.1, 33.9, 35.5, 37.2, 38.8, 40.5, 42.1, 43.8, 45.5, 47.2, 48.8, 50.4])

# %%
shut9 = np.array([1.8, 3.4, 5.1, 6.7, 8.4, 10.1, 11.7, 13.5, 15.1, 16.7, 18.4, 20.1, 20.7, 23.4, 25.0, 26.8, 28.4, 30.1, 31.7, 33.4, 35.1, 36.8, 38.4, 40.1, 41.8, 43.4, 45.1, 46.8, 48.4, 50.2])

# %%
open95 = np.array([2.2, 3.7, 5.4, 6.9, 8.5, 10.1, 11.2, 13.2, 14.8, 16.4, 18.0, 19.5, 21.1, 22.2, 24.3, 25.9, 27.5, 29.0, 30.6, 32.2, 33.8, 35.3, 36.9, 38.5, 40.1, 41.6, 43.2, 44.8, 46.4, 48.0, 49.5, 51.1])

# %%
shut95 = np.array([0.8, 2.4, 3.9, 5.5, 7.1, 8.2, 10.3, 11.8, 13.4, 15.0, 16.1, 18.1, 19.7, 21.3, 22.9, 24.4, 26.1, 27.6, 29.2, 30.7, 32.4, 33.9, 35.5, 37.1, 38.7, 40.3, 41.9, 43.4, 45.0, 46.6, 48.1, 49.0, 49.8, 51.3])

# %%
open10 = np.array([2.1, 3.6, 5.1, 6.8, 8.1, 9.8, 11.3, 12.6, 14.2, 15.7, 17.1, 18.6, 20.1, 21.7, 23.2, 24.6, 26.2, 27.7, 29.1, 30.7, 32.2, 33.7, 35.1, 36.7, 38.1, 39.7, 41.3, 42.6, 44.2, 45.6, 47.2, 48.7, 50.1])

# %%
shut10 = np.array([0.9, 2.7, 4.0, 5.4, 7.3, 8.4, 10.1, 11.8, 13.0, 14.6, 16.2, 17.4, 19.1, 20.7, 21.9, 23.6, 25.1, 26.4, 28.2, 29.5, 31.0, 32.7, 33.9, 35.6, 37.2, 38.4, 40.0, 41.7, 43.0, 44.6, 46.2, 47.5, 49.1, 50.5])

# %%
np.savez('waveguidexband', open75=open75, shut75=shut75, open8=open8, shut8=shut8, open85=open85, open9=open9, shut9=shut9, open95=open95, shut95=shut95, open10=open10, shut10=shut10)

# %%
npz = np.load('waveguidexband.npz')

# %%
open10 = npz['open10']

# %%
open10
# Out:
# array([  2.1,   3.6,   5.1,   6.8,   8.1,   9.8,  11.3,  12.6,  14.2,
#         15.7,  17.1,  18.6,  20.1,  21.7,  23.2,  24.6,  26.2,  27.7,
#         29.1,  30.7,  32.2,  33.7,  35.1,  36.7,  38.1,  39.7,  41.3,
#         42.6,  44.2,  45.6,  47.2,  48.7,  50.1])
